# %% [markdown]
# Textblob

# %%
from textblob import TextBlob
# for checking sentiment thing we use TextBlob

# %%
sentence_1 = "i had a great time at the movie it was really funny"
sentence_2 = "i had a great time at the movie but the parking was terrible"
sentence_3 = "i had a great time at the movie but the parking wasn't great"
sentence_4 = "i went to see a movie"

# %%
print(sentence_1)
sentiment_score = TextBlob(sentence_1)
print(sentiment_score.sentiment.polarity)
# Out:
# i had a great time at the movie it was really funny
# 0.525

# %% [markdown]
# TextBlob returns a score between -1 and 1, where negative scores indicate negative sentiment, and positive scores indicate positive sentiment.

# %%
print(sentence_2)
sentiment_score_2 = TextBlob(sentence_2)
print(sentiment_score_2.sentiment.polarity)
# Out:
# i had a great time at the movie but the parking was terrible
# -0.09999999999999998

# %%
print(sentence_3)
sentiment_score_3 = TextBlob(sentence_3)
print(sentiment_score_3.sentiment.polarity)
# Out:
# i had a great time at the movie but the parking wasn't great
# 0.8

# %%
print(sentence_4)
sentiment_score_4 = TextBlob(sentence_4)
print(sentiment_score_4.sentiment.polarity)
# Out:
# i went to see a movie
# 0.0

# %% [markdown]
# VADER

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
vader_sentiment = SentimentIntensityAnalyzer()

# %%
print(sentence_1)
print(vader_sentiment.polarity_scores(sentence_1))
# Out:
# i had a great time at the movie it was really funny
# {'neg': 0.0, 'neu': 0.578, 'pos': 0.422, 'compound': 0.807}

# %% [markdown]
# The compond score gives us the overall score for the text and is scored the same as TextBlob between -1 and 1.

# %%
print(sentence_2)
print(vader_sentiment.polarity_scores(sentence_2))
# Out:
# i had a great time at the movie but the parking was terrible
# {'neg': 0.234, 'neu': 0.621, 'pos': 0.144, 'compound': -0.3818}

# %% [markdown]
# Pre-tranined Tranformaer

# %%
#Tranformer can understand context

# %%
import transformers
from transformers import pipeline

# %%
sentiment_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sentiment_pipeline = pipeline("sentiment-analysis")
#
# File D:\python-preprocessingText\.venv\Lib\site-packages\transformers\pipelines\__init__.py:1017, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1012         raise ValueError(
#    1013             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#    1014             " arguments might conflict, use only one.)"
#    1015         )
#    1016 if dtype is not None:
# -> 1017     if isinstance(dtype, str) and hasattr(torch, dtype):
#    1018         dtype = getattr(torch, dtype)
#    1019     model_kwargs["dtype"] = dtype
#
# NameError: name 'torch' is not defined

# %%
sentence_1 = "i had a great time at the movie it was really funny"
sentence_2 = "i had a great time at the movie but the parking was terrible"
sentence_3 = "i had a great time at the movie but the parking wasn't great"
sentence_4 = "i went to see a movie"

# %%
print(sentence_1)
sentiment_pipeline(sentence_1)
# Out:
# i had a great time at the movie it was really funny
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 print(sentence_1)
# ----> 2 sentiment_pipeline(sentence_1)
#
# NameError: name 'sentiment_pipeline' is not defined
